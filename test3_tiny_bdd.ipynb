# %% [markdown]
# <a href="https://colab.research.google.com/github/amit-paradkar/project3/blob/main/test3_tiny_bdd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import drive
drive.mount('/content/googledrive')
# Out:
# Mounted at /content/googledrive

# %%
'''
Set directories
'''
PROJECT_DIR='/content/googledrive/MyDrive/AIML_17/Project'
BASE_DIR = PROJECT_DIR + '/test3-tiny-bdd'
CODE_DIR=BASE_DIR + '/BDD100k-YOLOV3-tiny'
DARKNET_DIR = CODE_DIR + '/darknet'
BDD_DIR = CODE_DIR + '/bdd100k'

# %%
'''
Create label to text files
'''
os.chdir(BASE_DIR)
# !ls
# Out:
# BDD100k-YOLOV3-tiny  test3-tiny-bdd.ipynb

# %%
'''
Create label to text for trainingfiles
'''
# !python /content/googledrive/MyDrive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/utils/label_to_txt.py -l '/content/googledrive/MyDrive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/bdd100k/labels' -d '/content/googledrive/MyDrive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/test_files/train'
# Out:
# tcmalloc: large alloc 1451204608 bytes == 0x560a06366000 @  0x7f94598281e7 0x560a03b3af98 0x560a03b05e27 0x560a03c84115 0x560a03c1e888 0x560a03b096f2 0x560a03be7c6e 0x560a03c1e802 0x560a03b096f2 0x560a03b0c926 0x560a03c877a3 0x560a03b09349 0x560a03bfae1d 0x560a03b7ce99 0x560a03b77ced 0x560a03b0abda 0x560a03b7cd00 0x560a03b0aafa 0x560a03b78915 0x560a03b0aafa 0x560a03b78915 0x560a03b779ee 0x560a03b776f3 0x560a03c414c2 0x560a03c4183d 0x560a03c416e6 0x560a03c19163 0x560a03c18e0c 0x7f9458612bf7 0x560a03c18cea
# ...

# %%
# !ls
# Out:
# bdd100k  darknet  LICENSE    setup.sh	     train.txt	val	 yolov3.gif
# config	 data	  README.md  tiny-bdd.ipynb  utils	val.txt  yolov3.jpg

# %%
# !ls '/content/googledrive/MyDrive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/bdd100k/images/train' | wc -l
# Out:
# 44860

# %%
'''
Remove images without labels
'''
# !python /content/googledrive/MyDrive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/utils/rm_imgs_without_labels.py -l '/content/googledrive/MyDrive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/bdd100k/labels' -d '/content/googledrive/MyDrive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/bdd100k/images'

# %%
'''
Create label to text files for test
'''
# !python /content/googledrive/MyDrive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/utils/label_to_txt.py -l '/content/googledrive/MyDrive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/bdd100k/labels/bdd100k_labels_images_val.json' -d '/content/googledrive/MyDrive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/val.txt'

# %%
BASE_DIR=PROJECT_DIR + '/test3-tiny-bdd/BDD100k-YOLOV3-tiny/train.txt'
os.chdir(BASE_DIR)
# !ls
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-3a3fe8b40e5e> in <module>()
#       2
#       3 BASE_DIR=PROJECT_DIR + '/test3-tiny-bdd/BDD100k-YOLOV3-tiny/train.txt'
# ----> 4 os.chdir(BASE_DIR)
#       5 get_ipython().system('ls')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/googledrive/MyDrive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/train.txt'

# %%
BASE_DIR=PROJECT_DIR + '/test3-tiny-bdd/BDD100k-YOLOV3-tiny/val'
os.chdir(BASE_DIR)
# !ls

# %%
'''
Create test and validation text file
'''
# !python /content/googledrive/MyDrive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/utils/test_val_txt.py -l '/content/googledrive/MyDrive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/bdd100k/images/train' -d '/content/googledrive/MyDrive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/bdd100k/images/test'
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/googledrive/MyDrive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/bdd100k/images/test/d2cdb093-049dcc29.jpg
# /content/googledrive/MyDrive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/bdd100k/images/test/d4768d85-0c6a7875.jpg
# /content/googledrive/MyDrive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/bdd100k/images/test/d2bf2973-83023002.jpg
# /content/googledrive/MyDrive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/bdd100k/images/test/d443a56f-6237a5a6.jpg
# /content/googledrive/MyDrive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/bdd100k/images/test/d4679f19-120243c2.jpg
# /content/googledrive/MyDrive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/bdd100k/images/test/d52369bc-c927d17d.jpg
# /content/googledrive/MyDrive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/bdd100k/images/test/d28db996-94eb3cd0.jpg
# ...

# %%
'''
Confirm train.txt and val.txt files are created
'''
# !ls -al train.txt val.txt
# Out:
# -rw------- 1 root root 5517780 Dec 19 09:34 train.txt
# -rw------- 1 root root 2440000 Dec 19 09:34 val.txt

# %%
'''
Copy train.txt and val.txt to bdd100k_data folder
'''
# !cp val.txt '/content/googledrive/My Drive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/darknet/bdd100k_data'

# %%
'''
Confirm content of bdd100k_data folder
'''
# !ls '/content/googledrive/My Drive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/darknet/bdd100k_data'
# Out:
# backup	      bdd100k.names	 train.txt  yolov3-tiny-BDD100k.cfg
# bdd100k.data  darknet53.conv.74  val.txt

# %%
# !ls '/content/googledrive/My Drive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/darknet/bdd100k_data'
# Out:
# bdd100k  darknet  LICENSE    setup.sh	     train.txt	val	 yolov3.gif
# config	 data	  README.md  tiny-bdd.ipynb  utils	val.txt  yolov3.jpg

# %%
# !ls /content/googledrive/My Drive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/

# %%
# !ls '/content/googledrive/My Drive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/config/yolov3-tiny-BDD100k.cfg.gdoc'
# Out:
# '/content/googledrive/My Drive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/config/yolov3-tiny-BDD100k.cfg.gdoc'

# %%
# !cp '/content/googledrive/My Drive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/data/bdd100k.data' '/content/googledrive/My Drive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/darknet/bdd100k_data'

# %%
# !cp '/content/googledrive/My Drive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/data/bdd100k.names' '/content/googledrive/My Drive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/darknet/bdd100k_data'

# %%
'''
Setup darknet
'''
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2021-12-18 16:20:55--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  36.3MB/s    in 4.7s
#
# 2021-12-18 16:21:00 (32.7 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
# !ls -al darknet53.conv.74
# Out:
# -rw------- 1 root root 162482580 Mar 25  2018 darknet53.conv.74

# %%
# !cp darknet53.conv.74 '/content/googledrive/My Drive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/darknet/bdd100k_data'

# %%
# !cp '/content/googledrive/My Drive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/darknet/bdd100k_data/darknet53.conv.74' '/content/googledrive/My Drive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/darknet/bdd100k_data/backup'

# %%
# !ls '/content/googledrive/My Drive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/darknet/bdd100k_data/backup'
# Out:
# darknet53.conv.74

# %%
# !ls /content/googledrive/MyDrive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/darknet
# Out:
# backup	      data	    libdarknet.so  LICENSE.gpl	 Makefile   results
# bdd100k_data  examples	    LICENSE	   LICENSE.meta  obj	    scripts
# cfg	      include	    LICENSE.fuck   LICENSE.mit	 python     src
# darknet       libdarknet.a  LICENSE.gen    LICENSE.v1	 README.md

# %%
# !cd '/content/googledrive/MyDrive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/darknet'

# %%
os.chdir(DARKNET_DIR)
# !ls bdd100k_data
# Out:
# backup	      bdd100k.names	 train.txt  yolov3-tiny-BDD100k.cfg
# bdd100k.data  darknet53.conv.74  val.txt

# %%
# !cp bdd100k_data/backup/darknet53.conv.74 backup

# %%
# !cp bdd100k_data/backup/darknet53.conv.74 .

# %%
# !ls -al
# Out:
# total 160914
# drwx------ 2 root root      4096 Dec 18 16:52 backup
# drwx------ 4 root root      4096 Dec 18 16:22 bdd100k_data
# drwx------ 2 root root      4096 Dec 12 06:29 cfg
# -rwx------ 1 root root    730568 Dec 12 06:29 darknet
# -rw------- 1 root root 162482580 Dec 18 16:53 darknet53.conv.74
# drwx------ 3 root root      4096 Dec 12 06:29 data
# drwx------ 2 root root      4096 Dec 12 06:29 examples
# drwx------ 8 root root      4096 Dec 12 06:28 .git
# -rw------- 1 root root       200 Dec 12 06:29 .gitignore
# drwx------ 2 root root      4096 Dec 12 06:29 include
# drwx------ 2 root root      4096 Dec 12 06:48 .ipynb_checkpoints
# -rw------- 1 root root    832718 Dec 12 06:29 libdarknet.a
# -rw------- 1 root root    622776 Dec 12 06:29 libdarknet.so
# -rw------- 1 root root       515 Dec 12 06:29 LICENSE
# -rw------- 1 root root       474 Dec 12 06:29 LICENSE.fuck
# -rw------- 1 root root      6652 Dec 12 06:29 LICENSE.gen
# ...

# %%
# !ls -al backup
# Out:
# total 158675
# -rw------- 1 root root 162482580 Dec 18 16:52 darknet53.conv.74

# %%
# !pwd
# Out:
# /content/googledrive/My Drive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny

# %%
# !ls -al darknet
# Out:
# total 160914
# drwx------ 2 root root      4096 Dec 12 06:29 backup
# drwx------ 4 root root      4096 Dec 19 04:18 bdd100k_data
# drwx------ 2 root root      4096 Dec 12 06:29 cfg
# -rw------- 1 root root    730568 Dec 12 06:29 darknet
# -rw------- 1 root root 162482580 Dec 18 16:53 darknet53.conv.74
# drwx------ 2 root root      4096 Dec 12 06:29 data
# drwx------ 2 root root      4096 Dec 12 06:29 examples
# drwx------ 2 root root      4096 Dec 12 06:28 .git
# -rw------- 1 root root       200 Dec 12 06:29 .gitignore
# drwx------ 2 root root      4096 Dec 12 06:29 include
# drwx------ 2 root root      4096 Dec 12 06:48 .ipynb_checkpoints
# -rw------- 1 root root    832718 Dec 12 06:29 libdarknet.a
# -rw------- 1 root root    622776 Dec 12 06:29 libdarknet.so
# -rw------- 1 root root       515 Dec 12 06:29 LICENSE
# -rw------- 1 root root       474 Dec 12 06:29 LICENSE.fuck
# -rw------- 1 root root      6652 Dec 12 06:29 LICENSE.gen
# ...

# %%
# !cd darknet

# %%
# !ls -al
# Out:
# total 63488
# drwx------  4 root root     4096 Dec 12 08:17 bdd100k
# drwx------  2 root root     4096 Dec 12 06:21 config
# drwx------ 15 root root     4096 Dec 12 06:28 darknet
# drwx------  2 root root     4096 Dec 12 06:21 data
# -rw-------  1 root root    35149 Dec 12 05:55 LICENSE
# -rw-------  1 root root     3979 Dec 12 05:55 README.md
# -rw-------  1 root root        0 Dec 12 05:55 setup.sh
# drwx------  3 root root     4096 Dec 19 06:27 test_files
# -rw-------  1 root root    15009 Dec 12 06:30 tiny-bdd.ipynb
# -rw-------  1 root root  5517780 Dec 19 09:34 train.txt
# drwx------  2 root root     4096 Dec 12 06:21 utils
# -rw-------  1 root root  2440000 Dec 19 09:34 val.txt
# -rw-------  1 root root 56722667 Dec 12 05:55 yolov3.gif
# -rw-------  1 root root   251173 Dec 12 05:55 yolov3.jpg

# %%
os.chdir(DARKNET_DIR)
# !ls bdd100k_data
# Out:
# backup		  bdd100k.data	 darknet53.conv.74  val.txt
# backup-train.txt  bdd100k.names  train.txt	    yolov3-tiny-BDD100k.cfg

# %%
# !pwd
# Out:
# /content/googledrive/MyDrive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/darknet

# %%
# !ls -al
# Out:
# total 166302
# drwx------ 2 root root      4096 Dec 12 06:29 backup
# drwx------ 4 root root      4096 Dec 12 06:48 bdd100k_data
# drwx------ 2 root root      4096 Dec 12 06:29 cfg
# -rw------- 1 root root    730568 Dec 12 06:29 darknet
# -rw------- 1 root root 162482580 Dec 18 16:53 darknet53.conv.74
# drwx------ 2 root root      4096 Dec 12 06:29 data
# drwx------ 2 root root      4096 Dec 12 06:29 examples
# drwx------ 2 root root      4096 Dec 12 06:28 .git
# -rw------- 1 root root       200 Dec 12 06:29 .gitignore
# drwx------ 2 root root      4096 Dec 12 06:29 include
# drwx------ 2 root root      4096 Dec 12 06:48 .ipynb_checkpoints
# -rw------- 1 root root    832718 Dec 12 06:29 libdarknet.a
# -rw------- 1 root root    622776 Dec 12 06:29 libdarknet.so
# -rw------- 1 root root       515 Dec 12 06:29 LICENSE
# -rw------- 1 root root       474 Dec 12 06:29 LICENSE.fuck
# -rw------- 1 root root      6652 Dec 12 06:29 LICENSE.gen
# ...

# %%
# !chmod +x darknet

# %%
# !pwd
# Out:
# /content/googledrive/My Drive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/darknet

# %%
# !ls backup
# Out:
# darknet53.conv.74

# %%
! ./darknet detector train bdd100k_data/bdd100k.data bdd100k_data/yolov3-tiny-BDD100k.cfg darknet53.conv.74
# Out:
# yolov3-tiny-BDD100k
# layer     filters    size              input                output
#     0 conv     16  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  16  0.150 BFLOPs
#     1 max          2 x 2 / 2   416 x 416 x  16   ->   208 x 208 x  16
#     2 conv     32  3 x 3 / 1   208 x 208 x  16   ->   208 x 208 x  32  0.399 BFLOPs
#     3 max          2 x 2 / 2   208 x 208 x  32   ->   104 x 104 x  32
#     4 conv     64  3 x 3 / 1   104 x 104 x  32   ->   104 x 104 x  64  0.399 BFLOPs
#     5 max          2 x 2 / 2   104 x 104 x  64   ->    52 x  52 x  64
#     6 conv    128  3 x 3 / 1    52 x  52 x  64   ->    52 x  52 x 128  0.399 BFLOPs
#     7 max          2 x 2 / 2    52 x  52 x 128   ->    26 x  26 x 128
#     8 conv    256  3 x 3 / 1    26 x  26 x 128   ->    26 x  26 x 256  0.399 BFLOPs
#     9 max          2 x 2 / 2    26 x  26 x 256   ->    13 x  13 x 256
#    10 conv    512  3 x 3 / 1    13 x  13 x 256   ->    13 x  13 x 512  0.399 BFLOPs
# ...

# %%
'''
Delete reference of files not present from train.txt
'''
# !grep -v  "6739851f-37c84296" /content/googledrive/MyDrive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/darknet/bdd100k_data/train.txt > reverser-train.txt

# %%
'''
Delete reference of files not present from train.txt
'''
# !mv reverser-train.txt train1.txt

# %%
'''
Delete reference of files not present from train.txt
'''
# !cp train1.txt /content/googledrive/MyDrive/AIML_17/Project/test3-tiny-bdd/BDD100k-YOLOV3-tiny/darknet/bdd100k_data
